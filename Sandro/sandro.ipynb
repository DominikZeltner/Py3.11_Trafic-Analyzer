# %% [markdown]
# # Daten der Verkehrszählung zum motorisierten Individualverkehr (Stundenwerte)

# %% [markdown]
# Laden der benötigten Bibliotheken

# %%
import pandas as pd

# %% [markdown]
# Laden der Daten für das Jahr 2022

# %%
# load the data for 2022
verkehrszaehlung_2022 = pd.read_csv("sid_dav_verkehrszaehlung_miv_od2031_2022.csv", sep=",", encoding="utf-8")

display(verkehrszaehlung_2022.head(5))
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_19964\1428122992.py:2: DtypeWarning: Columns (5,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   verkehrszaehlung_2022 = pd.read_csv("sid_dav_verkehrszaehlung_miv_od2031_2022.csv", sep=",", encoding="utf-8")
#        MSID     MSName  ZSID                              ZSName       Achse  \
# 0  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 1  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 2  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 3  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 4  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
#
#    HNr      Hoehe      EKoord     NKoord  Richtung  ...  \
# 0  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 1  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 2  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 3  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 4  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
#
#                     Kname AnzDetektoren  D1ID       D2ID       D3ID  \
# 0  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 1  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 2  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 3  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 4  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
#
#         D4ID       MessungDatZeit   LieferDat AnzFahrzeuge  AnzFahrzeugeStatus
# 0  Unbekannt  2022-01-01T00:00:00  2023-01-01        166.0            Gemessen
# 1  Unbekannt  2022-01-01T01:00:00  2023-01-01        255.0            Gemessen
# 2  Unbekannt  2022-01-01T02:00:00  2023-01-01        168.0            Gemessen
# 3  Unbekannt  2022-01-01T03:00:00  2023-01-01         96.0            Gemessen
# 4  Unbekannt  2022-01-01T04:00:00  2023-01-01         63.0            Gemessen
#
# [5 rows x 21 columns]

# %% [markdown]
# Laden der Daten für das Jahr 2023

# %%
# load the data for 2023
verkehrszaehlung_2023 = pd.read_csv("sid_dav_verkehrszaehlung_miv_od2031_2023.csv", sep=",", encoding="utf-8")

display(verkehrszaehlung_2023.head(5))
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_19964\2347122759.py:2: DtypeWarning: Columns (5,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   verkehrszaehlung_2023 = pd.read_csv("sid_dav_verkehrszaehlung_miv_od2031_2023.csv", sep=",", encoding="utf-8")
#        MSID     MSName  ZSID                              ZSName       Achse  \
# 0  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 1  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 2  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 3  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
# 4  Z001M001  Unbekannt  Z001  Seestrasse (Strandbad Wollishofen)  Seestrasse
#
#    HNr      Hoehe      EKoord     NKoord  Richtung  ...  \
# 0  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 1  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 2  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 3  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
# 4  451  Unbekannt  2683009.89  1243936.2  auswärts  ...
#
#                     Kname AnzDetektoren  D1ID       D2ID       D3ID  \
# 0  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 1  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 2  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 3  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
# 4  Badanstalt Wollishofen             1     2  Unbekannt  Unbekannt
#
#         D4ID       MessungDatZeit   LieferDat AnzFahrzeuge  AnzFahrzeugeStatus
# 0  Unbekannt  2023-01-01T00:00:00  2024-04-17        226.0            Gemessen
# 1  Unbekannt  2023-01-01T01:00:00  2024-04-17        438.0            Gemessen
# 2  Unbekannt  2023-01-01T02:00:00  2024-04-17        175.0            Gemessen
# 3  Unbekannt  2023-01-01T03:00:00  2024-04-17        101.0            Gemessen
# 4  Unbekannt  2023-01-01T04:00:00  2024-04-17         71.0            Gemessen
#
# [5 rows x 21 columns]

# %% [markdown]
# Konvertierung der Datumsfelder

# %%
verkehrszaehlung_2022["MessungDatZeit"] = pd.to_datetime(verkehrszaehlung_2022["MessungDatZeit"])
verkehrszaehlung_2022["LieferDat"] = pd.to_datetime(verkehrszaehlung_2022["LieferDat"])

print(verkehrszaehlung_2022.info())

verkehrszaehlung_2023["MessungDatZeit"] = pd.to_datetime(verkehrszaehlung_2023["MessungDatZeit"])
verkehrszaehlung_2023["LieferDat"] = pd.to_datetime(verkehrszaehlung_2023["LieferDat"])

print(verkehrszaehlung_2023.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1594138 entries, 0 to 1594137
# Data columns (total 21 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   MSID                1594138 non-null  object
#  1   MSName              1594138 non-null  object
#  2   ZSID                1594138 non-null  object
#  3   ZSName              1594138 non-null  object
#  4   Achse               1594138 non-null  object
#  5   HNr                 1594138 non-null  object
#  6   Hoehe               1594138 non-null  object
#  7   EKoord              1594138 non-null  float64
#  8   NKoord              1594138 non-null  float64
#  9   Richtung            1594138 non-null  object
#  10  Knummer             1594138 non-null  int64
#  11  Kname               1594138 non-null  object
#  12  AnzDetektoren       1594138 non-null  int64
#  13  D1ID                1594138 non-null  int64
#  14  D2ID                1594138 non-null  object
#  15  D3ID                1594138 non-null  object
#  16  D4ID                1594138 non-null  object
#  17  MessungDatZeit      1594138 non-null  datetime64[ns]
#  18  LieferDat           1594138 non-null  datetime64[ns]
#  19  AnzFahrzeuge        1478811 non-null  float64
#  20  AnzFahrzeugeStatus  1594138 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 255.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612474 entries, 0 to 1612473
# Data columns (total 21 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   MSID                1612474 non-null  object
#  1   MSName              1612474 non-null  object
#  2   ZSID                1612474 non-null  object
#  3   ZSName              1612474 non-null  object
#  4   Achse               1612474 non-null  object
#  5   HNr                 1612474 non-null  object
#  6   Hoehe               1612474 non-null  object
#  7   EKoord              1612474 non-null  float64
#  8   NKoord              1612474 non-null  float64
#  9   Richtung            1612474 non-null  object
#  10  Knummer             1612474 non-null  int64
#  11  Kname               1612474 non-null  object
#  12  AnzDetektoren       1612474 non-null  int64
#  13  D1ID                1612474 non-null  int64
#  14  D2ID                1612474 non-null  object
#  15  D3ID                1612474 non-null  object
#  16  D4ID                1612474 non-null  object
#  17  MessungDatZeit      1612474 non-null  datetime64[ns]
#  18  LieferDat           1612474 non-null  datetime64[ns]
#  19  AnzFahrzeuge        1523313 non-null  float64
#  20  AnzFahrzeugeStatus  1612474 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 258.3+ MB
# None

# %% [markdown]
# Durchschnittliches Verkehrsaufkommen pro Strasse und Monat für 2022

# %%
verkehrszaehlung_mean_2022 = (
    verkehrszaehlung_2022
    .groupby([verkehrszaehlung_2022["MessungDatZeit"].dt.to_period("M"), "ZSName", "Achse", "HNr", "Richtung"])
    .agg(
        AnzFahrzeuge=("AnzFahrzeuge", "mean"),
    )
    .reset_index()
    .sort_values(["ZSName", "Achse", "HNr", "Richtung", "MessungDatZeit"])
)

display(verkehrszaehlung_mean_2022.head())
# Out:
#     MessungDatZeit                           ZSName     Achse        HNr  \
# 0          2022-01  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 182        2022-02  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 365        2022-03  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 548        2022-04  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 730        2022-05  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
#
#             Richtung  AnzFahrzeuge
# 0    Uetlibergtunnel    584.161290
# 182  Uetlibergtunnel    643.635417
# 365  Uetlibergtunnel    683.880215
# 548  Uetlibergtunnel    654.065278
# 730  Uetlibergtunnel    690.930108

# %% [markdown]
# Durchschnittliches Verkehrsaufkommen pro Strasse und Monat für 2023

# %%
verkehrszaehlung_mean_2023 = (
    verkehrszaehlung_2023
    .groupby([verkehrszaehlung_2023["MessungDatZeit"].dt.to_period("M"), "ZSName", "Achse", "HNr", "Richtung"])
    .agg(
        AnzFahrzeuge=("AnzFahrzeuge", "mean"),
    )
    .reset_index()
    .sort_values(["ZSName", "Achse", "HNr", "Richtung", "MessungDatZeit"])
)

display(verkehrszaehlung_mean_2023.head())
# Out:
#     MessungDatZeit                           ZSName     Achse        HNr  \
# 0          2023-01  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 182        2023-02  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 365        2023-03  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 548        2023-04  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 730        2023-05  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
#
#             Richtung  AnzFahrzeuge
# 0    Uetlibergtunnel    626.044355
# 182  Uetlibergtunnel    651.878193
# 365  Uetlibergtunnel    680.713324
# 548  Uetlibergtunnel    648.045833
# 730  Uetlibergtunnel    672.427224

# %% [markdown]
# Verknüpfung der Daten der Jahre 2022 und 2023

# %%
verkehrszaehlung_mean_2022["Monat"] = verkehrszaehlung_mean_2022["MessungDatZeit"].dt.month
verkehrszaehlung_mean_2023["Monat"] = verkehrszaehlung_mean_2023["MessungDatZeit"].dt.month

verkehrszaehlung_mean = pd.merge(verkehrszaehlung_mean_2022, verkehrszaehlung_mean_2023, left_on=["Monat", "ZSName", "Achse", "HNr", "Richtung"], right_on=["Monat", "ZSName", "Achse", "HNr", "Richtung"], how='inner')

display(verkehrszaehlung_mean.head())
# Out:
#   MessungDatZeit_x                           ZSName     Achse        HNr  \
# 0          2022-01  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 1          2022-02  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 2          2022-03  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 3          2022-04  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
# 4          2022-05  A3W (A4 Uetlibergtunnel Brunau)  A3W (A4)  Unbekannt
#
#           Richtung  AnzFahrzeuge_x  Monat MessungDatZeit_y  AnzFahrzeuge_y
# 0  Uetlibergtunnel      584.161290      1          2023-01      626.044355
# 1  Uetlibergtunnel      643.635417      2          2023-02      651.878193
# 2  Uetlibergtunnel      683.880215      3          2023-03      680.713324
# 3  Uetlibergtunnel      654.065278      4          2023-04      648.045833
# 4  Uetlibergtunnel      690.930108      5          2023-05      672.427224

# %% [markdown]
# Liste der Strassen und Monate mit dem höchsten Zuwachs

# %%
# Calculate the increase in percent
verkehrszaehlung_mean['Zunahme_In_Prozent'] = (((verkehrszaehlung_mean['AnzFahrzeuge_y'] - verkehrszaehlung_mean['AnzFahrzeuge_x'])) / verkehrszaehlung_mean['AnzFahrzeuge_x']) * 100

# Sort by the increase in AnzFahrzeuge and get the top 20
top_20 = verkehrszaehlung_mean.sort_values(by='Zunahme_In_Prozent', ascending=False).head(20)

display(top_20)
# Out:
#      MessungDatZeit_x                                    ZSName  \
# 1852          2022-11               Talstrasse (Pelikanstrasse)
# 1494          2022-02     Schwamendingerstrasse (Dörflistrasse)
# 2079          2022-10  Winterthurerstrasse (Luchswiesenstrasse)
# 2080          2022-11  Winterthurerstrasse (Luchswiesenstrasse)
# 2078          2022-09  Winterthurerstrasse (Luchswiesenstrasse)
# 2087          2022-06  Winterthurerstrasse (Luchswiesenstrasse)
# 1851          2022-10               Talstrasse (Pelikanstrasse)
# 1853          2022-12               Talstrasse (Pelikanstrasse)
# 2075          2022-06  Winterthurerstrasse (Luchswiesenstrasse)
# 2088          2022-07  Winterthurerstrasse (Luchswiesenstrasse)
# 1850          2022-09               Talstrasse (Pelikanstrasse)
# 1847          2022-06               Talstrasse (Pelikanstrasse)
# 2086          2022-05  Winterthurerstrasse (Luchswiesenstrasse)
# 1505          2022-01     Schwamendingerstrasse (Dörflistrasse)
# 2092          2022-11  Winterthurerstrasse (Luchswiesenstrasse)
# 730           2022-08           Gutstrasse (Burstwiesenstrasse)
# 2076          2022-07  Winterthurerstrasse (Luchswiesenstrasse)
# 2175          2022-07              Zollikerstrasse (Höschgasse)
# 1818          2022-01         Stockerstrasse (Dreikönigstrasse)
# 1068          2022-09           Limmatquai (Rudolf-Brun-Brücke)
#
#                       Achse        HNr            Richtung  AnzFahrzeuge_x  \
# 1852             Talstrasse  Unbekannt           Sihlporte      153.844444
# 1494  Schwamendingerstrasse  Unbekannt            Oerlikon      117.857143
# 2079    Winterthurerstrasse  Unbekannt            auswärts      172.235215
# 2080    Winterthurerstrasse  Unbekannt            auswärts      183.146067
# 2078    Winterthurerstrasse  Unbekannt            auswärts      171.820833
# 2087    Winterthurerstrasse  Unbekannt            einwärts      196.905028
# 1851             Talstrasse  Unbekannt           Sihlporte      186.133065
# 1853             Talstrasse  Unbekannt           Sihlporte      168.579301
# 2075    Winterthurerstrasse  Unbekannt            auswärts      200.692737
# 2088    Winterthurerstrasse  Unbekannt            einwärts      175.411290
# 1850             Talstrasse  Unbekannt           Sihlporte      202.413889
# 1847             Talstrasse  Unbekannt           Sihlporte      207.886111
# 2086    Winterthurerstrasse  Unbekannt            einwärts      196.823925
# 1505  Schwamendingerstrasse  Unbekannt      Schwamendingen      140.052419
# 2092    Winterthurerstrasse  Unbekannt            einwärts      205.896067
# 730              Gutstrasse        116            Hubertus       85.064865
# 2076    Winterthurerstrasse  Unbekannt            auswärts      184.159946
# 2175        Zollikerstrasse         85            einwärts       70.846774
# 1818         Stockerstrasse         38    Stauffacherplatz       99.528226
# 1068             Limmatquai  Unbekannt  Rudolf-Brun-Brücke       51.762500
#
#       Monat MessungDatZeit_y  AnzFahrzeuge_y  Zunahme_In_Prozent
# 1852     11          2023-11      247.405556           60.815398
# 1494      2          2023-02      174.437500           48.007576
# 2079     10          2023-10      250.826613           45.630272
# 2080     11          2023-11      265.318056           44.866914
# 2078      9          2023-09      247.891667           44.273347
# 2087      6          2023-06      278.266667           41.320244
# 1851     10          2023-10      251.741935           35.248370
# 1853     12          2023-12      225.759409           33.918819
# 2075      6          2023-06      268.341667           33.707712
# 2088      7          2023-07      231.798376           32.145642
# 1850      9          2023-09      265.330556           31.083177
# 1847      6          2023-06      270.158333           29.954970
# 2086      5          2023-05      255.362903           29.741800
# 1505      1          2023-01      180.494624           28.876477
# 2092     11          2023-11      263.559722           28.006195
# 730       8          2023-08      108.423181           27.459417
# 2076      7          2023-07      232.956698           26.496941
# 2175      7          2023-07       88.813172           25.359514
# 1818      1          2023-01      123.962366           24.549960
# 1068      9          2023-09       64.287500           24.197054

# %% [markdown]
# Unnötige Spalten entfernen

# %%
new_df = top_20[["Monat", "ZSName", "Achse", "HNr", "Richtung", "Zunahme_In_Prozent"]].copy()

display(new_df)
# Out:
#       Monat                                    ZSName                  Achse  \
# 1852     11               Talstrasse (Pelikanstrasse)             Talstrasse
# 1494      2     Schwamendingerstrasse (Dörflistrasse)  Schwamendingerstrasse
# 2079     10  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 2080     11  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 2078      9  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 2087      6  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 1851     10               Talstrasse (Pelikanstrasse)             Talstrasse
# 1853     12               Talstrasse (Pelikanstrasse)             Talstrasse
# 2075      6  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 2088      7  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 1850      9               Talstrasse (Pelikanstrasse)             Talstrasse
# 1847      6               Talstrasse (Pelikanstrasse)             Talstrasse
# 2086      5  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 1505      1     Schwamendingerstrasse (Dörflistrasse)  Schwamendingerstrasse
# 2092     11  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 730       8           Gutstrasse (Burstwiesenstrasse)             Gutstrasse
# 2076      7  Winterthurerstrasse (Luchswiesenstrasse)    Winterthurerstrasse
# 2175      7              Zollikerstrasse (Höschgasse)        Zollikerstrasse
# 1818      1         Stockerstrasse (Dreikönigstrasse)         Stockerstrasse
# 1068      9           Limmatquai (Rudolf-Brun-Brücke)             Limmatquai
#
#             HNr            Richtung  Zunahme_In_Prozent
# 1852  Unbekannt           Sihlporte           60.815398
# 1494  Unbekannt            Oerlikon           48.007576
# 2079  Unbekannt            auswärts           45.630272
# 2080  Unbekannt            auswärts           44.866914
# 2078  Unbekannt            auswärts           44.273347
# 2087  Unbekannt            einwärts           41.320244
# 1851  Unbekannt           Sihlporte           35.248370
# 1853  Unbekannt           Sihlporte           33.918819
# 2075  Unbekannt            auswärts           33.707712
# 2088  Unbekannt            einwärts           32.145642
# 1850  Unbekannt           Sihlporte           31.083177
# 1847  Unbekannt           Sihlporte           29.954970
# 2086  Unbekannt            einwärts           29.741800
# 1505  Unbekannt      Schwamendingen           28.876477
# 2092  Unbekannt            einwärts           28.006195
# 730         116            Hubertus           27.459417
# 2076  Unbekannt            auswärts           26.496941
# 2175         85            einwärts           25.359514
# 1818         38    Stauffacherplatz           24.549960
# 1068  Unbekannt  Rudolf-Brun-Brücke           24.197054
